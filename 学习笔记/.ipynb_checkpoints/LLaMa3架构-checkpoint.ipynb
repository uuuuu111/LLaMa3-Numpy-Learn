# %% [markdown]
# [论文精读](https://www.bilibili.com/video/BV1WM4m1y7Uh?vd_source=0d567fd8ba32ba934dec5ee477e4de17)

# %% [markdown]
# ## 1. 架构总览
# ![image.png](attachment:e4c61f22-1f7e-43b8-a125-6acc6fb7e599.png)

# %% [markdown]
# ## 2. 详细介绍
# ### 2.1 Tokenizer 分词
# 将word序列（句子）转换为number序列
# ### 2.2 Embedding 词嵌入
# ### 2.3 Decoder Only Transformer Blocks 仅包含解码器的transformer
# ![image.png](attachment:0310e40c-4f73-4bf2-9426-a2b869ee0f15.png)
# #### 2.3.1 RMSNorm 层归一化
# #### 2.3.2 SwiGLUFFN 前馈网络
# #### 2.3.3 MHA 多头注意力机制

# %% [markdown]
# # 项目代码总览
# ![image.png](attachment:a81de82b-266b-4b7f-908e-0b74739da772.png)
